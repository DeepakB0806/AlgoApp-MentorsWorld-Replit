# %%
pip install "git+https://github.com/Kotak-Neo/Kotak-neo-api-v2.git@v2.0.1#egg=neo_api_client"
# Out:
# Collecting neo_api_client
#   Cloning https://github.com/Kotak-Neo/Kotak-neo-api-v2.git (to revision v2.0.1) to /tmp/pip-install-81dc9pjp/neo-api-client_04ad3deebc584996ac5260c9d9a2c03e
#   Running command git clone --filter=blob:none --quiet https://github.com/Kotak-Neo/Kotak-neo-api-v2.git /tmp/pip-install-81dc9pjp/neo-api-client_04ad3deebc584996ac5260c9d9a2c03e
#   Resolved https://github.com/Kotak-Neo/Kotak-neo-api-v2.git to commit 1533903cb5db1a50892223b404d753dbc8fba50e
#   Preparing metadata (setup.py) ... done
# Collecting bidict==0.22.1 (from neo_api_client)
#   Downloading bidict-0.22.1-py3-none-any.whl.metadata (10 kB)
# Collecting certifi==2022.12.7 (from neo_api_client)
#   Downloading certifi-2022.12.7-py3-none-any.whl.metadata (2.9 kB)
# Collecting idna==2.10 (from neo_api_client)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting numpy==2.1.0 (from neo_api_client)
#   Downloading numpy-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.7 MB/s eta 0:00:00
# Collecting pyjsparser==2.7.1 (from neo_api_client)
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting PyJWT==2.6.0 (from neo_api_client)
#   Downloading PyJWT-2.6.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-dateutil==2.8.2 (from neo_api_client)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting python-dotenv==1.0.0 (from neo_api_client)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting requests==2.32.3 (from neo_api_client)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting six==1.16.0 (from neo_api_client)
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting urllib3==1.26.14 (from neo_api_client)
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 3.0 MB/s eta 0:00:00
# Collecting websocket-client==1.8.0 (from neo_api_client)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting websockets==8.1 (from neo_api_client)
#   Downloading websockets-8.1.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pandas==2.2.3 (from neo_api_client)
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.9 MB/s eta 0:00:00
# Collecting asyncio==3.4.3 (from neo_api_client)
#   Downloading asyncio-3.4.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->neo_api_client) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->neo_api_client) (2026.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->neo_api_client) (3.4.7)
# Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 6.1 MB/s eta 0:00:00
# Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.6 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.8 MB/s eta 0:00:00
# Downloading numpy-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 54.7 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 96.9 MB/s eta 0:00:00
# Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 15.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.9 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 9.8 MB/s eta 0:00:00
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.7 MB/s eta 0:00:00
# Building wheels for collected packages: neo_api_client, pyjsparser, websockets
#   Building wheel for neo_api_client (setup.py) ... done
#   Created wheel for neo_api_client: filename=neo_api_client-2.0.0-py3-none-any.whl size=46525 sha256=97af5dd8d1c911502100aea1df1440aefadd808f581051cb417c4c2c885fabe2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8a3wiid2/wheels/98/2a/c1/1abf101b27a4e3dec2eec443245a84c355fd6a843986404219
#   Building wheel for pyjsparser (setup.py) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25982 sha256=690d465d29c0852314d842d4e8567786801f0635270441dca7fa6fa5b9ba986a
#   Stored in directory: /root/.cache/pip/wheels/14/32/1d/9ef7b582e358446aeef4b9052aa89ef4dffa1688c1aae8aa13
#   Building wheel for websockets (setup.py) ... done
#   Created wheel for websockets: filename=websockets-8.1-cp312-cp312-linux_x86_64.whl size=74194 sha256=04db199e8e58f240f486e345b7e65ad994a3e6e15e98dfa6aea299d8a116adac
#   Stored in directory: /root/.cache/pip/wheels/04/4b/92/86e53875ed9a5976cb84a5479730bd2498892de8ffdf47d8c1
# Successfully built neo_api_client pyjsparser websockets
# Installing collected packages: pyjsparser, asyncio, websockets, websocket-client, urllib3, six, python-dotenv, PyJWT, numpy, idna, certifi, bidict, requests, python-dateutil, pandas, neo_api_client
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.9.0
#     Uninstalling websocket-client-1.9.0:
#       Successfully uninstalled websocket-client-1.9.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.2
#     Uninstalling python-dotenv-1.2.2:
#       Successfully uninstalled python-dotenv-1.2.2
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.12.1
#     Uninstalling PyJWT-2.12.1:
#       Successfully uninstalled PyJWT-2.12.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2026.2.25
#     Uninstalling certifi-2026.2.25:
#       Successfully uninstalled certifi-2026.2.25
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# mcp 1.27.0 requires pyjwt[crypto]>=2.10.1, but you have pyjwt 2.6.0 which is incompatible.
# google-adk 1.29.0 requires python-dateutil<3.0.0,>=2.9.0.post0, but you have python-dateutil 2.8.2 which is incompatible.
# google-adk 1.29.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 1.29.0 requires websockets<16.0.0,>=15.0.1, but you have websockets 8.1 which is incompatible.
# blobfile 3.2.0 requires urllib3>=2, but you have urllib3 1.26.14 which is incompatible.
# gradio-client 1.14.0 requires websockets<16.0,>=13.0, but you have websockets 8.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.0 which is incompatible.
# dataproc-spark-connect 1.1.0 requires websockets>=14.0, but you have websockets 8.1 which is incompatible.
# curl-cffi 0.15.0 requires certifi>=2024.2.2, but you have certifi 2022.12.7 which is incompatible.
# google-genai 1.68.0 requires websockets<17.0,>=13.0.0, but you have websockets 8.1 which is incompatible.
# holidays 0.94 requires python-dateutil<3,>=2.9.0.post0, but you have python-dateutil 2.8.2 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 8.1 which is incompatible.
# Successfully installed PyJWT-2.6.0 asyncio-3.4.3 bidict-0.22.1 certifi-2022.12.7 idna-2.10 neo_api_client-2.0.0 numpy-2.1.0 pandas-2.2.3 pyjsparser-2.7.1 python-dateutil-2.8.2 python-dotenv-1.0.0 requests-2.32.3 six-1.16.0 urllib3-1.26.14 websocket-client-1.8.0 websockets-8.1

# %%
from neo_api_client import NeoAPI



# access_token: It is optional.
# environment: You pass prod to connect to live server
# neo_fin_key: It is optional. Pass None.
# consumer_key: this is the token that is available on your NEO app or website.
# To get consumer key, login to kotak NEO app or web -> invest tab -> trade api card. Generate application.
# with default application, you will have a copyable token. Pass this token in consumer_key.

client = NeoAPI(environment='prod', access_token=None, neo_fin_key=None, consumer_key='135590e4-fda5-4869-be21-91c354efa4f2')

# %%
client.totp_login(mobile_number="+919820114252", ucc="2KVW9", totp='929547')
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..AdHnRM2o91-DdUZD1BAmVUmdIBigIqXyskPEhMDEmCw3J5vEiEC6egXLfLCppe_AbHrsIUVwbRSPTOaVwYnlhqV98BYHag2XDGDvevL5glwPO9D4jOcnJakoSXUEmIc54vK00c4iV1F8rCzJ6MEyqKZck2ggtqIQKVrarMb139n-zfS0fMamZxl7McxykzB2yAxqu8rGIHznWwM4c2kCN383qdxmq95r1m1d2gTI_y4TwaNWMZJ4_n24zQDqJO5E0fH3zYv4KPMPnS9uvZ8NWCPeXc7gFRoQibx6xyNPHzDTRSCbQU1hV4-dJnPiqsmFGdaceBqoi7id6UE6j89U0A',
#   'sid': '0a12d369-0274-414a-a511-643b864d6144',
#   'rid': '40cb9499-7812-4339-ad6a-056eb3a0d36b',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'ucc': '2KVW9',
#   'greetingName': 'SAUGATO',
#   'isTrialAccount': False,
#   'dataCenter': 'E41',
#   'derivativesRiskDisclosure': 'Risk Disclosure on Derivatives\n\nAs per a SEBI study dated 25 Jan 2023- \n• 9 out of 10 individual traders in equity Futures and Options Segment, incurred net losses.\n• On an average, loss makers registered net trading loss close to Rs.50,000.\n• Over and above the net trading losses incurred, loss makers expended an additional 28% of net trading losses as transaction costs.\n• Those making net trading profits, incurred between 15% to 50% of such profits as transaction cost.\n\nFor more information please check out : https://www.sebi.gov.in/reports-and-statistics/research/jan-2023/study-analysis-of-profit-and-loss-of-individual-traders-dealing-in-equity-fando-segment_67525.html',
#   'mfAccess': 1,
#   'dataCenterMap': None,
#   'dormancyStatus': 'A',
#   'asbaStatus': '',
#   'clientType': 'RI',
#   'isNRI': False,
#   'kId': 'AETPR9446J',
#   'kType': 'View',
#   'status': 'success',
#   'incRange': 0,
#   'incUpdFlag': '',
#   'clientGroup': '',
#   'kraStatus': '',
#   'rcFlag': 0}}

# %%
client.totp_validate(mpin="080680")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..i37itbt8CP1Ubeb871kiTzePTtOwAV6f3mrcgT1FjTSAQ_sW60VWb-Ff7fGsy4iW8fAvsZWtWvg96P2_pcosHnuK2a9xRgDkXR7CyNmGW06cYdvMkcR2bMYOHwwLLNeZlb9eUro9rt9u7aKaWquW4l_5NpPoepZB44dtrvcmD_3C7I_5_5ws7klOXGklCWbWhu-QM-JyYPQf1UXu74FgPAwy2QSb63jMyL7J3z618AeM9l6layiEPS4b-2vstrv8Iit4GpNIP0F9lPdAoZEvWBmkJxC8AE-wzzOe0CbM4g2wxRcasCUYx0Fcz4_EYYR8b8NYK3zsuuqd8JEbeZ3ThQ',
#   'sid': '0c23acf4-2f86-4d08-aef1-240fe829b10a',
#   'rid': '40cb9499-7812-4339-ad6a-056eb3a0d36b',
#   'baseUrl': 'https://e41.kotaksecurities.com',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'ucc': '2KVW9',
#   'greetingName': 'SAUGATO',
#   'isTrialAccount': False,
#   'dataCenter': 'E41',
#   'derivativesRiskDisclosure': 'Risk Disclosure on Derivatives\n\nAs per a SEBI study dated 25 Jan 2023- \n• 9 out of 10 individual traders in equity Futures and Options Segment, incurred net losses.\n• On an average, loss makers registered net trading loss close to Rs.50,000.\n• Over and above the net trading losses incurred, loss makers expended an additional 28% of net trading losses as transaction costs.\n• Those making net trading profits, incurred between 15% to 50% of such profits as transaction cost.\n\nFor more information please check out : https://www.sebi.gov.in/reports-and-statistics/research/jan-2023/study-analysis-of-profit-and-loss-of-individual-traders-dealing-in-equity-fando-segment_67525.html',
#   'mfAccess': 1,
#   'dataCenterMap': None,
#   'dormancyStatus': 'A',
#   'asbaStatus': '',
#   'clientType': 'RI',
#   'isNRI': False,
#   'kId': 'AETPR9446J',
#   'kType': 'Trade',
#   'status': 'success',
#   'incRange': 0,
#   'incUpdFlag': '',
#   'clientGroup': '',
#   'kraStatus': '',
#   'rcFlag': 0}}
